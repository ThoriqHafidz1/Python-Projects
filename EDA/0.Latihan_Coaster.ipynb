# %% [markdown]
# Source : https://youtu.be/xi0vhXFPegw?si=9WYO5EG5zENeZHXK

# %% [markdown]
# # 0. Import Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
#os.listdir('drive/MyDrive/Colab Notebooks/Rob Dulla Youtube')
os.chdir('drive/MyDrive/Colab Notebooks/Rob Dulla Youtube')

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %%
os.listdir()
df = pd.read_csv('0.coaster_db.csv')
df.head(5)
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %% [markdown]
# # 1. Understanding Data

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head(5)
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %% [markdown]
# # 2. Preparing Data

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df = df[['coaster_name',
    #'Length', 'Speed',
    'Location', 'Status',
    #'Opening date',
      # 'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
      # 'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date', 'Opened', 'Replaced by', 'Website',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',

    'year_introduced', 'latitude', 'longitude', 'Type_Main','opening_date_clean',
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph',
    #'height_value', 'height_unit',
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()
df
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df.columns = [col.title() for col in df.columns]
df
df = df.rename(columns={'Opening_Date_Clean':'Opening_Date', 'Inversions_Clean':'Inversion','Gforce_Clean':'Gforce' })
df
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Year_Introduced', 'Latitude',
#        'Longitude', 'Type_Main', 'Opening_Date', 'Speed_Mph', 'Height_Ft',
#        'Inversion', 'Gforce'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Coaster_Name        object
# Location            object
# Status              object
# Year_Introduced      int64
# Latitude           float64
# Longitude          float64
# Type_Main           object
# Opening_Date        object
# Speed_Mph          float64
# Height_Ft          float64
# Inversion            int64
# Gforce             float64
# dtype: object

# %%
df['Opening_Date'] = pd.to_datetime(df['Opening_Date'])
df.dtypes
# Out:
# Coaster_Name               object
# Location                   object
# Status                     object
# Year_Introduced             int64
# Latitude                  float64
# Longitude                 float64
# Type_Main                  object
# Opening_Date       datetime64[ns]
# Speed_Mph                 float64
# Height_Ft                 float64
# Inversion                   int64
# Gforce                    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Year_Introduced      0
# Latitude           275
# Longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_Mph          150
# Height_Ft          916
# Inversion            0
# Gforce             725
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Year_Introduced, Latitude, Longitude, Type_Main, Opening_Date, Speed_Mph, Height_Ft, Inversion, Gforce]
# Index: []

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status  Year_Introduced  Latitude  Longitude Type_Main  \
# 43               Removed             1927   42.8617   -79.0598      Wood
# ...

# %%
df.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status  Year_Introduced  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed             1926
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed             1927
#
#     Latitude  Longitude Type_Main Opening_Date  Speed_Mph  Height_Ft  \
# 39   42.8617   -79.0598      Wood   1926-01-01       60.0        NaN
# 43   42.8617   -79.0598      Wood   1926-01-01       60.0        NaN
#
#     Inversion  Gforce
# 39          0     4.0
# 43          0     4.0

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])].sort_values(by=['Coaster_Name']).head(20)
# Out:
#                           Coaster_Name                  Location  \
# 780         Afterburn (roller coaster)                 Carowinds
# 270                     Alpine Bobsled                     Other
# 435                     Alpine Bobsled                     Other
# 686            American Dreier Looping                     Other
# 738            American Dreier Looping                     Other
# 1082           American Dreier Looping                     Other
# 859      Arkham Asylum – Shock Therapy  Warner Bros. Movie World
# 829                        Astro Storm                     Other
# 348                   Batman: The Ride                     Other
# 414                   Batman: The Ride                     Other
# 332                   Batman: The Ride                     Other
# 625                   Batman: The Ride                     Other
# 470                   Batman: The Ride                     Other
# ...

# %%
df.loc[df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])].sort_values(by=['Coaster_Name']).head(30)
# Out:
#                           Coaster_Name                  Location  \
# 780         Afterburn (roller coaster)                 Carowinds
# 270                     Alpine Bobsled                     Other
# 435                     Alpine Bobsled                     Other
# 686            American Dreier Looping                     Other
# 738            American Dreier Looping                     Other
# 1082           American Dreier Looping                     Other
# 859      Arkham Asylum – Shock Therapy  Warner Bros. Movie World
# 829                        Astro Storm                     Other
# 348                   Batman: The Ride                     Other
# 414                   Batman: The Ride                     Other
# 332                   Batman: The Ride                     Other
# 625                   Batman: The Ride                     Other
# 470                   Batman: The Ride                     Other
# ...

# %%
df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])].sort_values(by=['Coaster_Name'])
# Out:
#                       Coaster_Name                  Location     Status  \
# 696    10 Inversion Roller Coaster        Chimelong Paradise  Operating
# 886         Abyss (roller coaster)           Adventure World  Operating
# 1057                       Abyssus              Energylandia  Operating
# 828   Accelerator (roller coaster)             Drayton Manor  Operating
# 936       Acrobat (roller coaster)        Nagashima Spa Land  Operating
# ...                            ...                       ...        ...
# 48            Zip (roller coaster)       Oaks Amusement Park    Removed
# 56                   Zipper Dipper  Blackpool Pleasure Beach  Operating
# 16                   Zippin Pippin                     Other        NaN
# 434     Zoomerang (Lake Compounce)            Lake Compounce  Operating
# 562                  Zydeco Scream                     Other        NaN
#
#       Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed_Mph  \
# ...

# %%
df = df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])].reset_index(drop=True).copy()
df
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %% [markdown]
# # 3. Feature Understanding

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1952     1
# 1956     1
# 1961     1
# 1955     1
# 1959     1
# Name: count, Length: 101, dtype: int64

# %%
ax = df['Year_Introduced'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Top 10 Years Coaster Introduced')
ax.set_xlabel('Year_Introduced')
ax.set_ylabel('Count')

ax.bar_label(ax.containers[0]) # memberikan data value label
# Out:
# [Text(0, 0, '46'),
#  Text(0, 0, '45'),
#  Text(0, 0, '30'),
#  Text(0, 0, '29'),
#  Text(0, 0, '28'),
#  Text(0, 0, '27'),
#  Text(0, 0, '25'),
#  Text(0, 0, '24'),
#  Text(0, 0, '24'),
#  Text(0, 0, '23')]

# %%
ax = df['Speed_Mph'].plot(kind='hist', bins=20, title = 'Coaster Speed Mph')
ax.set_xlabel('Speed Mph')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '10'),
#  Text(0, 0, '15'),
#  Text(0, 0, '46'),
#  Text(0, 0, '71'),
#  Text(0, 0, '133'),
#  Text(0, 0, '116'),
#  Text(0, 0, '197'),
#  Text(0, 0, '113'),
#  Text(0, 0, '62'),
#  Text(0, 0, '50'),
#  Text(0, 0, '18'),
#  Text(0, 0, '7'),
#  Text(0, 0, '4'),
#  Text(0, 0, '3'),
#  Text(0, 0, '2'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '0'),
#  Text(0, 0, '1')]

# %%
ax = df['Speed_Mph'].plot(kind='kde', title='Coaster Speed')
ax.set_xlabel('speed')

mean_val = df['Speed_Mph'].mean()
ax.axvline(mean_val, color='red', linestyle='--')
ax.text(mean_val, 0, f'Mean={mean_val:.1f}', rotation=90, va='bottom', ha='right')
# Out:
# Text(49.01764705882353, 0, 'Mean=49.0')

# %% [markdown]
# # 4. Feature Relationship

# %%
# Coaster Speed bs Height using matplotlib
df.plot(kind='scatter', x = 'Speed_Mph', y = 'Height_Ft',
title = 'Coaster Speed vs Height')

plt.show()

# %%
# Coaster Speed vs Height using SEABORN

ax = sns.scatterplot(x = 'Speed_Mph', y = 'Height_Ft', data = df,
                     hue = 'Year_Introduced')
ax.set_title('Coaster Speed vs Height')
plt.show()

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Year_Introduced', 'Latitude',
#        'Longitude', 'Type_Main', 'Opening_Date', 'Speed_Mph', 'Height_Ft',
#        'Inversion', 'Gforce'],
#       dtype='object')

# %%
sns.pairplot(data = df, vars = ['Year_Introduced', 'Speed_Mph', 'Height_Ft', 'Inversion', 'Gforce'], hue = 'Type_Main')

# %%
df_corr = df[['Year_Introduced','Speed_Mph', 'Height_Ft', 'Inversion', 'Gforce' ]].corr()
df_corr
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
df_corr = df[['Year_Introduced','Speed_Mph', 'Height_Ft', 'Inversion', 'Gforce' ]].dropna().corr()
df_corr
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Step 5: Ask a Question about the data
# - Try to answer a question you have about the data using a plot or statistic.
#
# What are the locations with the fastest roller coasters (minimum of 10)?

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Year_Introduced', 'Latitude',
#        'Longitude', 'Type_Main', 'Opening_Date', 'Speed_Mph', 'Height_Ft',
#        'Inversion', 'Gforce'],
#       dtype='object')

# %%
df['Location'].value_counts()
# Out:
# Location
# Other                       181
# Kings Island                 19
# Cedar Point                  18
# Six Flags Magic Mountain     17
# Hersheypark                  16
#                            ...
# China Dinosaurs Park          1
# Legoland Billund              1
# Happy Valley Tianjin          1
# Adlabs Imagica                1
# Epcot                         1
# Name: count, Length: 280, dtype: int64

# %%
ax = df.query('Location != "Other"')\
  .groupby('Location')['Speed_Mph']\
  .agg(['mean','count'])\
  .query('count >= 10')\
  .sort_values('mean',ascending=True)['mean']\
  .plot(kind = 'barh', title= ('Top Average Fastest Coaster by Location '))
ax.set_xlabel ('Speed (Mph)')
ax.bar_label(ax.containers[0])
plt.show()
